// %% [markdown]
// # Laboratório em Estruturas de Programação Java
//
// O laboratório a seguir serve para praticar estruturas de programação Java sem compromisso com a orientação a objetos.

// %% [markdown]
// ## Desafio 1 - Empréstimo
//
// Em um financiamento com juros compostos e número de parcelas fixas parte-se dos seguintes parâmetros:
// * `S` - valor da primeira parcela
// * `N` - número de parcelas
// * `J` - percentual de juros mensal
//
// A primeira parcela a ser paga do financiamento é sempre igual a `S`. A partir daí é feita uma atualização mensal da parcela, em que cada nova parcela é calculada a partir da parcela do mês anterior, conforme a fórmula:
//
// > Parcela<sub>mês</sub> = Parcela<sub>mês-1</sub> * (1 + `J` / 100)
//
// O financiamento encerra quando as `N` parcelas são pagas.
//
// Exemplo:
// * `S`: 200
// * `N`: 5
// * `J`: 1%
//
// Parcelas do financiamento:
// `200`; `202`; `204.02`; `206.06`; `208.12`

// %% [markdown]
// ### Desafio 1 / Parte 1 - Escrevendo o programa sem módulos
//
// Dado o problema descrito, escreva um programa que calcule as parcelas de um empréstimo para os seguintes valores:
// * S: 200
// * N: 5
// * J: 1%
//
// Nesta versão não use outro módulo além da função principal.

// %%
int S = 200;
    int N = 5;
    float J = 1;
    float parcela = S;

    for(int i = 1; i <= N; i++) {
        System.out.format("Parcela %d: %.2f%n", i, parcela);
        parcela = parcela*(1 + J/100);
    }
// Out:
// Parcela 1: 200.00
// Parcela 2: 202.00
// Parcela 3: 204.02
// Parcela 4: 206.06
// Parcela 5: 208.12
// null

// %% [markdown]
// ### Desafio 1 / Parte 2 - Escrevendo módulos
//
// Reescreva o código acima de forma que seu programa faça uso de uma função que seja responsável pelo cálculo de uma parcela X do empréstimo. Podem ser usadas mais funções (métodos) conforme a necessidade.

// %%
public class Emprestimo {
    static int self_S;
    static int self_N;
    static float self_J;
    static int atual;
    static float parcela;
    
    static void novo_emprestimo(int S, int N, float J) {
        self_S = S;
        self_N = N;
        self_J = J;
        atual = 1;
        parcela = S;
    }
    
    static float proximaParcela() {
        float retorno = parcela;
        atual++;
        
        if(atual <= self_N)
            parcela = parcela*(1 + self_J/100);
        else
            parcela = 0;
        
        return retorno;
    }
// Out:
// com.twosigma.beaker.javash.bkr36a524c2.Emprestimo

// %%
Emprestimo.novo_emprestimo(200, 5, 1);
int i = 1;

float parcela = Emprestimo.proximaParcela();

while(parcela > 0){
    System.out.format("Parcela %d: %.2f%n", i, parcela);
    parcela = Emprestimo.proximaParcela();
    i++;
}
// Out:
// Parcela 1: 200.00
// Parcela 2: 202.00
// Parcela 3: 204.02
// Parcela 4: 206.06
// Parcela 5: 208.12
// null

// %% [markdown]
// ## Desafio 2
//
// Escreva um programa que sorteie um número inteiro entre `0` e `9999` o número deve ser mostrado, em seguida convertido para binário e a versão binária deve ser apresentada no console. A conversão decimal/binário deve ser computada por um programa feito por você.

// %%
public class Conversor{
    static String converteBinario(int numero){
        String binario = "";
        while(numero > 0) {
            binario = ((numero % 2) == 0 ? "0" : "1") + binario;
            numero = numero / 2;
        }
        
        return binario;
    }
}
// Out:
// com.twosigma.beaker.javash.bkr2e680d03.Conversor

// %%
import java.util.Random;

Random rand = new Random();
int numero = rand.nextInt(10000);
System.out.println(Conversor.converteBinario(numero));
// Out:
// 1110100000110
// null

// %% [markdown]
// ## Desafio 3
//
// Uma molécula de DNA pode ser definida a partir de uma cadeia que representa a sequência de suas bases:
// A - Adenina
// C - Citisina
// G - Guanina
// T - Tinina
//
// Desse modo, uma string pode ser usada para representar um segmento do DNA da seguinte maneira: `ATTACGCGCAAAC`.
//
// Escreva uma função (método) que codifique a cadeia de RNA produzida a partir de uma cadeia de DNA. A função deve ser genérica o suficiente para ser aplicável a qualquer cadeia. A entrada é uma string (DNA) e o retorno é uma string (RNA).
//
// Escreva um programa que teste esta função com uma cadeia de DNA de sua escolha.

// %%
public class Transcription{
    static String codifica(String dna){
        String rna = dna.replace('T', 'U');
        return rna;
    }
}
// Out:
// com.twosigma.beaker.javash.bkrffc525df.Transcription

// %%
String dna = "ATTACGCGCAAAC";
String rna = Transcription.codifica(dna);
System.out.println(rna);
// Out:
// AUUACGCGCAAAC
// null

// %% [markdown]
// ## Desafio 4
//
// Uma empresa precisa realizar uma estatística do salário de seus funcionários.
//
// Para fins de teste, os salários devem ser gerados aleatoriamente com valores variando entre R\\$ 2.500 e R\\$ 15.000.
//
// Escreva um programa que gere uma lista contendo os salários de 50 funcionários da empresa e mostre no console quantos funcionários ganham salário acima da média.

// %%
import java.util.Random;

public class Salario{
    static void lista_salarios(){
        Random rand = new Random();
        float media;
        float soma = 0;
        float salarios[] = new float[50];
        for(int i = 0; i < 50; i++){
            salarios[i] = rand.nextInt(15000 - 2500) + 2500;
            soma += salarios[i];
        }
        media = soma / 50;
        
        for(int i = 0; i < 50; i++){
            System.out.print("Funcionário " + (i+1) + ": " + salarios[i]);
            if(salarios[i] > media){
                System.out.print(" -- Acima da Média !");
                System.out.println();
            }
            else
                System.out.println();
            
        }
    }
}
// Out:
// com.twosigma.beaker.javash.bkr8d0d0088.Salario

// %%
Salario.lista_salarios();
// Out:
// Funcionário 1: 7709.0
// Funcionário 2: 6013.0
// Funcionário 3: 8082.0
// Funcionário 4: 6928.0
// Funcionário 5: 7310.0
// Funcionário 6: 6422.0
// Funcionário 7: 12833.0 -- Acima da Média !
// Funcionário 8: 5423.0
// Funcionário 9: 9211.0 -- Acima da Média !
// Funcionário 10: 8668.0 -- Acima da Média !
// Funcionário 11: 9669.0 -- Acima da Média !
// Funcionário 12: 7450.0
// Funcionário 13: 5443.0
// Funcionário 14: 6269.0
// Funcionário 15: 3943.0
// Funcionário 16: 11076.0 -- Acima da Média !
// Funcionário 17: 6805.0
// Funcionário 18: 9726.0 -- Acima da Média !
// Funcionário 19: 12317.0 -- Acima da Média !
// Funcionário 20: 5478.0
// Funcionário 21: 12187.0 -- Acima da Média !
// Funcionário 22: 11520.0 -- Acima da Média !
// Funcionário 23: 12252.0 -- Acima da Média !
// Funcionário 24: 3320.0
// Funcionário 25: 7913.0
// Funcionário 26: 5587.0
// Funcionário 27: 11586.0 -- Acima da Média !
// Funcionário 28: 4738.0
// Funcionário 29: 13039.0 -- Acima da Média !
// Funcionário 30: 10805.0 -- Acima da Média !
// Funcionário 31: 12439.0 -- Acima da Média !
// Funcionário 32: 11657.0 -- Acima da Média !
// Funcionário 33: 3099.0
// Funcionário 34: 3892.0
// Funcionário 35: 5841.0
// Funcionário 36: 8454.0
// Funcionário 37: 10451.0 -- Acima da Média !
// Funcionário 38: 7220.0
// Funcionário 39: 14142.0 -- Acima da Média !
// Funcionário 40: 10088.0 -- Acima da Média !
// Funcionário 41: 3671.0
// Funcionário 42: 6326.0
// Funcionário 43: 7781.0
// Funcionário 44: 12965.0 -- Acima da Média !
// Funcionário 45: 7520.0
// Funcionário 46: 6337.0
// Funcionário 47: 12094.0 -- Acima da Média !
// Funcionário 48: 10390.0 -- Acima da Média !
// Funcionário 49: 12602.0 -- Acima da Média !
// Funcionário 50: 14398.0 -- Acima da Média !
// null
